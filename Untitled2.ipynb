# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, precision_score, \
              recall_score, f1_score, precision_recall_curve, roc_curve, roc_auc_score, \
              auc, mean_squared_error, accuracy_score

import math
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
data_train = pd.read_csv('churn-bigml-80 .csv')
data_test = pd.read_csv('churn-bigml-20.csv')

# %%
data_train
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
data_train['Churn'] = data_train['Churn'].replace({True: 1, False: 0})
data_test['Churn'] = data_test['Churn'].replace({True: 1, False: 0})

# %%
data_train['International plan'] = data_train['International plan'].replace({'Yes': 1, 'No': 0})
data_train['Voice mail plan'] = data_train['Voice mail plan'].replace({'Yes': 1, 'No': 0})

data_test['International plan'] = data_test['International plan'].replace({'Yes': 1, 'No': 0})
data_test['Voice mail plan'] = data_test['Voice mail plan'].replace({'Yes': 1, 'No': 0})

# %%
data_train = data_train.drop(data_train.columns[[0]], axis = 1)

data_test = data_test.drop(data_test.columns[[0]], axis = 1)

# %%
data_test
# Out:
#      International plan  Voice mail plan  Number vmail messages  \
# 0                     0                0                      0
# 1                     0                0                      0
# 2                     0                0                      0
# 3                     0                0                      0
# 4                     0                0                      0
# ..                  ...              ...                    ...
# 662                   0                1                     26
# 663                   0                1                     29
# 664                   0                0                      0
# 665                   0                0                      0
# 666                   1                0                      0
#
#      Total day minutes  Total day calls  Total day charge  Total eve minutes  \
# 0                184.5               97             31.37              351.6
# ...

# %%
# !pip install tensorflow

# %%
data_train.shape
# Out:
# (2666, 17)

# %%
data_test.shape
# Out:
# (667, 17)
